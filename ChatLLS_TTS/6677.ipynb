# %%
# 使用本地模型用 

import ChatTTS
from IPython.display import Audio

base_path = r'F:\AI_LLM\ChatTTS-0601\ChatTTS'
chat = ChatTTS.Chat()
chat.load_models(source='local',local_path=base_path)
# Out:
# INFO:ChatTTS.core:Load from local: F:\AI_LLM\ChatTTS-0601\ChatTTS
# WARNING:ChatTTS.utils.gpu_utils:No GPU found, use CPU instead
# INFO:ChatTTS.core:use cpu
# INFO:ChatTTS.core:vocos loaded.
# INFO:ChatTTS.core:dvae loaded.
# INFO:ChatTTS.core:gpt loaded.
# INFO:ChatTTS.core:decoder loaded.
# INFO:ChatTTS.core:tokenizer loaded.
# INFO:ChatTTS.core:All initialized.

# %%
texts = ["我是一个小菜鸟",]

wavs = chat.infer(texts, use_decoder=True)
Audio(wavs[0], rate=24_000, autoplay=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 texts = ["我是一个小菜鸟",]
# ----> 3 wavs = chat.infer(texts, use_decoder=True)
#       4 Audio(wavs[0], rate=24_000, autoplay=True)
#
# NameError: name 'chat' is not defined

# %%
# 使用本地模型用 

import ChatTTS
from IPython.display import Audio

base_path = r'F:\AI_LLM\ChatTTS-0601\ChatTTS'
chat = ChatTTS.Chat()
chat.load_models(source='local',local_path=base_path)
# Out:
# 你好！很高兴见到你，有什么我可以帮你的吗？

# %%
# Please install OpenAI SDK first: `pip3 install openai`
# LLM
from openai import OpenAI

client = OpenAI(api_key="sk-3538c9d4b2ff4570bf37eb7aa84ad0c8", base_url="https://api.deepseek.com")
que = input("请提问")
response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": que},
    ],
    stream=False
)

# TTS
texts = [str(response.choices[0].message.content),]

wavs = chat.infer(texts, use_decoder=True)
Audio(wavs[0], rate=24_000, autoplay=True)
# Out:
# 请提问 今天天气怎么样
# INFO:httpx:HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Invalid characters found! : {'”', '“'}
#  30%|████████████████▎                                     | 116/384 [00:07<00:18, 14.66it/s]
#  49%|█████████████████████████▌                          | 1007/2048 [00:58<01:00, 17.30it/s]
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# llm & tts
# 使用本地模型用 

import ChatTTS
from IPython.display import Audio

base_path = r'F:\AI_LLM\ChatTTS-0601\ChatTTS'
chat = ChatTTS.Chat()
chat.load_models(source='local',local_path=base_path)
# Please install OpenAI SDK first: `pip3 install openai`
# LLM
from openai import OpenAI

client = OpenAI(api_key="sk-f7c458d3974545ce909fe62bc3684efb", base_url="https://api.deepseek.com")
que = input("请提问")
response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": que},
    ],
    stream=False
)

# TTS
texts = [str(response.choices[0].message.content),]
printf(texts)
wavs = chat.infer(texts, use_decoder=True)
Audio(wavs[0], rate=24_000, autoplay=True)
# Out:
# INFO:ChatTTS.core:Load from local: F:\AI_LLM\ChatTTS-0601\ChatTTS
# WARNING:ChatTTS.utils.gpu_utils:No GPU found, use CPU instead
# INFO:ChatTTS.core:use cpu
# INFO:ChatTTS.core:vocos loaded.
# INFO:ChatTTS.core:dvae loaded.
# INFO:ChatTTS.core:gpt loaded.
# INFO:ChatTTS.core:decoder loaded.
# INFO:ChatTTS.core:tokenizer loaded.
# INFO:ChatTTS.core:All initialized.
# 请提问 1+1总知道吧
# INFO:httpx:HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# INFO:ChatTTS.core:All initialized.
# WARNING:ChatTTS.core:Invalid characters found! : {'1', '2', '+'}
# ['是的，我知道。1+1 等于 2。这是一个基本的数学事实，适用于十进制系统。']
#  12%|██████▉                                                | 48/384 [00:03<00:22, 14.69it/s]
#  17%|█████████                                            | 350/2048 [00:17<01:23, 20.45it/s]
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
